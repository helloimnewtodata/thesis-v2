# %%
import refinitiv.data as rd
import pandas as pd
import numpy as np
import warnings

warnings.filterwarnings('ignore', category=FutureWarning)

rd.open_session()
# Out:
# <refinitiv.data.session.Definition object at 0x11170a030 {name='workspace'}>

# %%
universe = ["EURIBOR3MD="]

fields = ["TR.FIXINGVALUE",
          "TR.FIXINGVALUE.date"]

params = {
    "SDate": "2024-01-01",
    "EDate": "2026-03-05",
    "Frq": "D",
}

df = rd.get_data(universe=universe, 
                 fields=fields,
                 parameters=params)
df.head()
# Out:
#     Instrument  Fixing Value       Date
# 0  EURIBOR3MD=         3.909 2023-12-29
# 1  EURIBOR3MD=         3.905 2024-01-02
# 2  EURIBOR3MD=         3.929 2024-01-03
# 3  EURIBOR3MD=         3.922 2024-01-04
# 4  EURIBOR3MD=         3.936 2024-01-05
